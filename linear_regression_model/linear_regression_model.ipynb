# %% [markdown]
# # Linear Regression Model Based on Theory

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Genarating random data

# %%
m=52
x= np.linspace(0,1,m)
y= 15*x+ np.random.normal(0,0.4,x.shape)

# %% [markdown]
# ###  Ploting Generated Data

# %%
plt.plot(x,y,'ob')
plt.show()

# %%
w1= np.random.rand()
w0= np.random.rand()
print(w0,w1);
# Out:
# 0.10994961871844788 0.39869032907679036

# %%
lr = 0.5  # learning rate
err=1 # error
itr=1    # no of iterations
max_itr =100

J= np.zeros(max_itr)  # cost function
J[0]= (0.5/m)*np.sum((y-(w1*x)-w0)**2)


while err>1.e-5 and itr< max_itr:      # Stopping Criteria
    yh = w1*x +w0                   # ground truth
    Dj0 =(yh-y)                         #calculating gradient Descent
    dw0=- lr*np.sum(Dj0)/m
    Dj1 =(yh-y)*x
    dw1=- lr*np.sum(Dj1)/m
    w0 += dw0
    w1 += dw1

    itr = itr+1
    J[itr-1]= (0.5/m)*np.sum((y-(w1*x)-w0)**2)
    if max_itr>1:
        err = abs(J[itr-1] - J[itr-2])
    else:
        err=1
    # plt.clf()
    # plt.figure(figsize=(10, 6))
    # plt.subplot(211)
    # plt.plot(x,y,'o',label='Data')
    # plt.plot(x,yh,'r',label='Linear Fit')
    # plt.xlabel('x')
    # plt.ylabel('y')
    # plt.legend(loc='upper left')
    
    # plt.subplot(212)
    # plt.plot(np.arange(1,itr+1),J[:itr],'-og')
    # plt.xlabel('iterations')
    # plt.ylabel('Cost function (J) ')

    # plt.show()
    # plt.pause(0.2)

plt.show()
print('w0= ',w0)
print('w1= ',w1)
# Out:
# w0=  0.09538923050464752
# w1=  14.8957467082408

# %%
    # plt.clf()
    plt.figure(figsize=(10, 6))
    plt.subplot(211)
    plt.plot(x,y,'o',label='Data')
    plt.plot(x,yh,'r',label='Linear Fit')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend(loc='upper left')
    
    plt.subplot(212)
    plt.plot(np.arange(1,itr+1),J[:itr],'-og')
    plt.xlabel('iterations')
    plt.ylabel('Cost function (J) ')

    plt.show()
    # plt.pause(0.2)

# %% [markdown]
# # Scikit Learn Type

# %%
class LinearRegression:

    def __init__(self, lr = 0.001, n_iters = 1000):
        self.lr = lr
        self.n_iters = n_iters
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iters):
            y_pred = np.dot(X, self.weights) + self.bias

            dw = (1/n_samples) * np.dot(X.T, (y_pred-y))
            db = (1/n_samples) * np.sum(y_pred-y)

            self.weights = self.weights - self.lr * dw
            self.bias = self.bias - self.lr * db

    def predict(self, X):
        y_pred = np.dot(X, self.weights) + self.bias
        return y_pred
